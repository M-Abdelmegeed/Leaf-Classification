# %% [markdown]
# # Leaf Classification Problem
#
# ## Deep Learning Course Project Fall '23
#
# ### Members:
# - Mohammed Ahmed Abdelmegeed 19P1298
# - Sohayla Ihab Abdelmawgoud 19P7343
# - Nourhan Hatem Ibrahim 19P5821

# %% [markdown]
# ## Understanding The Dataset
#
# The dataset comprises a total of 1584 records, with 990 instances allocated for training in the `train.csv` file and the remaining 594 instances used for testing in the `test.csv` file.
#
# ### Attributes:
#
# - **id**: Identifier for each record
# - **margin1 - margin64**: Numerical features representing leaf margin characteristics
# - **shape1 - shape64**: Numerical features representing leaf shape characteristics
# - **texture1 - texture64**: Numerical features representing leaf texture characteristics
#
# The distribution of records in the dataset is as follows:
#
# - **Training Data (`train.csv`):** 990 records
# - **Testing Data (`test.csv`):** 594 records
#
# ### Images:
#
# The dataset includes a folder named **images** containing 1584 black and white JPG images of leaves. Each image corresponds to a record in the dataset and can be referenced using the respective **id**.

# %% [markdown]
# ## Loading & Exploring the Dataset

# %%
#importing the datasets

import pandas as pd

df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
#df_train.set_index('id', inplace=True)
#df_test.set_index('id', inplace=True)

# %%
df_train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0  ...   0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0  ...   0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0  ...   0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0  ...   0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0  ...   0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 1   0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 2   0.005859   0.000977   0.007812        0.0        0.0   0.000000
# 3   0.000000   0.000000   0.020508        0.0        0.0   0.017578
# 4   0.021484   0.000000   0.000000        0.0        0.0   0.000000
#
#    texture63  texture64
# 0   0.000000   0.025391
# 1   0.039062   0.022461
# 2   0.020508   0.002930
# 3   0.000000   0.047852
# 4   0.000000   0.031250
#
# [5 rows x 194 columns]

# %%
df_train.describe()
# Out:
#                 id     margin1     margin2     margin3     margin4  \
# count   990.000000  990.000000  990.000000  990.000000  990.000000
# mean    799.595960    0.017412    0.028539    0.031988    0.023280
# std     452.477568    0.019739    0.038855    0.025847    0.028411
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     415.250000    0.001953    0.001953    0.013672    0.005859
# 50%     802.500000    0.009766    0.011719    0.025391    0.013672
# 75%    1195.500000    0.025391    0.041016    0.044922    0.029297
# max    1584.000000    0.087891    0.205080    0.156250    0.169920
#
#           margin5     margin6     margin7     margin8     margin9  ...  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  ...
# mean     0.014264    0.038579    0.019202    0.001083    0.007167  ...
# std      0.018390    0.052030    0.017511    0.002743    0.008933  ...
# min      0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%      0.001953    0.000000    0.005859    0.000000    0.001953  ...
# 50%      0.007812    0.015625    0.015625    0.000000    0.005859  ...
# 75%      0.017578    0.056153    0.029297    0.000000    0.007812  ...
# max      0.111330    0.310550    0.091797    0.031250    0.076172  ...
#
#         texture55   texture56   texture57   texture58   texture59   texture60  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  990.000000
# mean     0.036501    0.005024    0.015944    0.011586    0.016108    0.014017
# std      0.063403    0.019321    0.023214    0.025040    0.015335    0.060151
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000977    0.000000    0.004883    0.000000
# 50%      0.004883    0.000000    0.005859    0.000977    0.012695    0.000000
# 75%      0.043701    0.000000    0.022217    0.009766    0.021484    0.000000
# max      0.429690    0.202150    0.172850    0.200200    0.106450    0.578130
#
#         texture61   texture62   texture63   texture64
# count  990.000000  990.000000  990.000000  990.000000
# mean     0.002688    0.020291    0.008989    0.019420
# std      0.011415    0.039040    0.013791    0.022768
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000977
# 50%      0.000000    0.003906    0.002930    0.011719
# 75%      0.000000    0.023438    0.012695    0.029297
# max      0.151370    0.375980    0.086914    0.141600
#
# [8 rows x 193 columns]

# %%
df_test.describe()
# Out:
#                 id     margin1     margin2     margin3     margin4  \
# count   594.000000  594.000000  594.000000  594.000000  594.000000
# mean    780.673401    0.017562    0.028425    0.031858    0.022556
# std     465.646977    0.019585    0.038351    0.025719    0.028797
# min       4.000000    0.000000    0.000000    0.000000    0.000000
# 25%     368.500000    0.001953    0.001953    0.013672    0.005859
# 50%     774.000000    0.009766    0.010743    0.023438    0.013672
# 75%    1184.500000    0.028809    0.041016    0.042969    0.027344
# max    1583.000000    0.085938    0.189450    0.167970    0.164060
#
#           margin5     margin6     margin7     margin8     margin9  ...  \
# count  594.000000  594.000000  594.000000  594.000000  594.000000  ...
# mean     0.014527    0.037497    0.019222    0.001085    0.007092  ...
# std      0.018029    0.051372    0.017122    0.002697    0.009515  ...
# min      0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%      0.001953    0.000000    0.005859    0.000000    0.001953  ...
# 50%      0.007812    0.013672    0.015625    0.000000    0.005859  ...
# 75%      0.019531    0.056641    0.029297    0.000000    0.007812  ...
# max      0.093750    0.271480    0.087891    0.021484    0.083984  ...
#
#         texture55   texture56   texture57   texture58   texture59   texture60  \
# count  594.000000  594.000000  594.000000  594.000000  594.000000  594.000000
# mean     0.035291    0.005923    0.015033    0.011762    0.015881    0.011217
# std      0.064482    0.026934    0.022318    0.024771    0.014898    0.052530
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000977    0.000000    0.004883    0.000000
# 50%      0.003906    0.000000    0.005859    0.001953    0.012695    0.000000
# 75%      0.038086    0.000000    0.019531    0.010498    0.022461    0.000000
# max      0.353520    0.441410    0.153320    0.177730    0.083984    0.606450
#
#         texture61   texture62   texture63   texture64
# count  594.000000  594.000000  594.000000  594.000000
# mean     0.002617    0.019975    0.009389    0.020970
# std      0.011204    0.034704    0.013457    0.023407
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000977
# 50%      0.000000    0.003418    0.002930    0.013184
# 75%      0.000000    0.022461    0.014648    0.032227
# max      0.123050    0.247070    0.086914    0.149410
#
# [8 rows x 193 columns]

# %% [markdown]
# Both train and test datasets have the same number of features, 192 features. Except that the train dataset has an extra column for species

# %% [markdown]
# ## Checking out Images
#
# Plotting a 4 random images to get a sense of how the dataset and images we are working on look like.

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

images_folder_path = "images"

jpg_files = [f for f in os.listdir(images_folder_path) if f.endswith(".jpg")]

random_jpgs = random.sample(jpg_files, 4)

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

for i, jpg in enumerate(random_jpgs):
    img_path = os.path.join(images_folder_path, jpg)
    img = mpimg.imread(img_path)
    axs[i // 2, i % 2].imshow(img)
    axs[i // 2, i % 2].set_title(f"Image {i+1}: {jpg}")
    axs[i // 2, i % 2].axis('off')

plt.show()

# %% [markdown]
# ### Visualizing Correlation Between Attributes

# %%
df_train_n = df_train.drop(columns = ['species'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#only numerical features

correlation_matrix_train = df_train_n.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix_train, cmap='coolwarm', annot=False)
plt.title('Correlation Matrix of Train Dataset')
plt.show()

# %%
correlation_matrix_test = df_test.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix_test, cmap='coolwarm', annot=False)
plt.title('Correlation Matrix of Test Dataset')
plt.show()

# %%
feature_check = ['margin1','margin5','margin9','shape1','shape5','shape9','texture1','texture5','texture9']
correlation_matrix_check = df_train_n[feature_check].corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix_check, cmap='coolwarm', annot=True)
plt.title('Correlation Matrix Check')
plt.show()

# %% [markdown]
# We can realize that a lot of attributes or features are really dependent on each other, hence we can drop a subset of them in order to make the training process much easier and less computationally expensive, but in order to do that, we have to identify all the highly correlated pairs first.

# %% [markdown]
# ## Preprocessing
#
# ### 1. Removing Highly Correlated Attributes
#
# The initial step in preprocessing involves the identification and removal of highly correlated attributes. This is crucial for mitigating multicollinearity, ensuring that the model isn't influenced by redundant information. Highly correlated attributes are detected through correlation analysis, and one feature from each correlated pair is dropped.
#
# ### 2. Checking for Missing Values and Duplicates
#
# Following the removal of highly correlated attributes, the dataset undergoes a check for missing values and duplicates. This step ensures data integrity and consistency.
#
# ### 3. Standardizing the Data
#
# Standardization becomes the next step to ensure that all numerical features are on a similar scale. This is achieved by subtracting the mean and dividing by the standard deviation of each feature.
#
# ### 4. Encoding Categorical Variables
#
# Encoding is applied to convert them into a format suitable for machine learning algorithms.

# %%
import numpy as np

correlation_threshold = 0.99

# print("Highly Correlated Feature Pairs:")
for i in range(len(correlation_matrix_train.columns)):
    for j in range(i):
        if abs(correlation_matrix_train.iloc[i, j]) > correlation_threshold:
            feature1 = correlation_matrix_train.columns[i]
            feature2 = correlation_matrix_train.columns[j]
            correlation_value = correlation_matrix_train.iloc[i, j]
            #print(f"{feature1} and {feature2} are highly correlated ({correlation_value:.2f})")

# %% [markdown]
# Repeat the analysis with test table to make sure the data is clean enough for the neural network. This is expected to increase accuracy

# %% [raw]
# '''for i in range(len(correlation_matrix_test.columns)):
#     for j in range(i):
#         if abs(correlation_matrix_test.iloc[i, j]) > correlation_threshold:
#             feature1t = correlation_matrix_test.columns[i]
#             feature2t = correlation_matrix_test.columns[j]
#             correlation_value = correlation_matrix.iloc[i, j]
#             #print(f"{feature1} and {feature2} are highly correlated ({correlation_value:.2f})")'''

# %% [markdown]
# ## 1. Feature Selection: Highly Correlated Features
#
# The following pairs of features are highly correlated:
#
# 1. shape10 and shape9 (Correlation: 0.99)
# 2. shape11 and shape10 (Correlation: 0.99)
# 3. shape12 and shape11 (Correlation: 0.99)
# 4. shape13 and shape12 (Correlation: 0.99)
# 5. shape14 and shape13 (Correlation: 0.99)
# 6. shape15 and shape14 (Correlation: 0.99)
# 7. shape16 and shape15 (Correlation: 0.99)
# 8. shape17 and shape16 (Correlation: 0.99)
# 9. shape18 and shape17 (Correlation: 0.99)
# 10. shape19 and shape18 (Correlation: 0.99)
# 11. shape20 and shape19 (Correlation: 0.99)
# 12. shape21 and shape20 (Correlation: 0.99)
# 13. shape22 and shape21 (Correlation: 0.99)
# 14. shape23 and shape22 (Correlation: 0.99)
# 15. shape43 and shape42 (Correlation: 0.99)
# 16. shape44 and shape43 (Correlation: 0.99)
# 17. shape45 and shape44 (Correlation: 0.99)
# 18. shape46 and shape45 (Correlation: 0.99)
# 19. shape47 and shape46 (Correlation: 0.99)
# 20. shape48 and shape47 (Correlation: 0.99)
# 21. shape49 and shape48 (Correlation: 0.99)
# 22. shape50 and shape49 (Correlation: 0.99)
# 23. shape51 and shape50 (Correlation: 0.99)
# 24. shape52 and shape51 (Correlation: 0.99)
# 25. shape53 and shape52 (Correlation: 0.99)
# 26. shape54 and shape53 (Correlation: 0.99)
#
# To avoid multicollinearity and reduce redundancy, it is recommended to drop one feature from each highly correlated pair. Since you want to drop only features with odd shape numbers, the following features will be dropped:
#
# ### Dropping Features:
#
# The following features will be dropped:
#
# - **Features to Drop:**
#   - shape9, shape11, shape13, shape15, shape17, shape19, shape21, shape43, shape45, shape47, shape49, shape51, shape53

# %%
features_to_drop = ['shape9', 'shape11', 'shape13', 'shape15', 'shape17', 'shape19', 'shape21',
                    'shape43', 'shape45', 'shape47', 'shape49', 'shape51', 'shape53']
df_train_dropped = df_train.drop(columns = features_to_drop)
df_test_dropped = df_test.drop(columns = features_to_drop)

# %%
df_train_dropped.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0  ...   0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0  ...   0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0  ...   0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0  ...   0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0  ...   0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 1   0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 2   0.005859   0.000977   0.007812        0.0        0.0   0.000000
# 3   0.000000   0.000000   0.020508        0.0        0.0   0.017578
# 4   0.021484   0.000000   0.000000        0.0        0.0   0.000000
#
#    texture63  texture64
# 0   0.000000   0.025391
# 1   0.039062   0.022461
# 2   0.020508   0.002930
# 3   0.000000   0.047852
# 4   0.000000   0.031250
#
# [5 rows x 181 columns]

# %% [markdown]
# We now have a total of 180 features, instead of 193. Of course more features could have been dropped if the **correlation_threshold** is reduced as it was set to 0.99.

# %%
df_test_dropped.head()
# Out:
#    id   margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0   4  0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 1   7  0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 2   9  0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 3  12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 4  13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
#
#    margin8   margin9  ...  texture55  texture56  texture57  texture58  \
# 0      0.0  0.005859  ...   0.006836   0.000000   0.015625   0.000977
# 1      0.0  0.033203  ...   0.000000   0.000000   0.006836   0.001953
# 2      0.0  0.011719  ...   0.128910   0.000000   0.000977   0.000000
# 3      0.0  0.003906  ...   0.012695   0.015625   0.002930   0.036133
# 4      0.0  0.005859  ...   0.000000   0.042969   0.016602   0.010742
#
#    texture59  texture60  texture61  texture62  texture63  texture64
# 0   0.015625        0.0        0.0   0.000000   0.003906   0.053711
# 1   0.013672        0.0        0.0   0.000977   0.037109   0.044922
# 2   0.000000        0.0        0.0   0.015625   0.000000   0.000000
# 3   0.013672        0.0        0.0   0.089844   0.000000   0.008789
# 4   0.041016        0.0        0.0   0.007812   0.009766   0.007812
#
# [5 rows x 180 columns]

# %% [markdown]
# ## 2. Checking for Duplicates and Missing Values

# %% [markdown]
# ### Checking for duplicates

# %%
duplicates = df_train_dropped[df_train_dropped.duplicated()]
print("Duplicate Rows:")
print(duplicates)
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [id, species, margin1, margin2, margin3, margin4, margin5, margin6, margin7, margin8, margin9, margin10, margin11, margin12, margin13, margin14, margin15, margin16, margin17, margin18, margin19, margin20, margin21, margin22, margin23, margin24, margin25, margin26, margin27, margin28, margin29, margin30, margin31, margin32, margin33, margin34, margin35, margin36, margin37, margin38, margin39, margin40, margin41, margin42, margin43, margin44, margin45, margin46, margin47, margin48, margin49, margin50, margin51, margin52, margin53, margin54, margin55, margin56, margin57, margin58, margin59, margin60, margin61, margin62, margin63, margin64, shape1, shape2, shape3, shape4, shape5, shape6, shape7, shape8, shape10, shape12, shape14, shape16, shape18, shape20, shape22, shape23, shape24, shape25, shape26, shape27, shape28, shape29, shape30, shape31, shape32, shape33, shape34, shape35, shape36, shape37, shape38, shape39, shape40, shape41, ...]
# Index: []
#
# [0 rows x 181 columns]

# %% [markdown]
# We have 0 rows in the duplicates dataframe, hence we have no duplicate rows at all.

# %% [markdown]
# ### Checking for missing values

# %%
missing_values = df_train_dropped.isnull().sum()
print("\nMissing Values per Column:")
print(missing_values)
# Out:
# Missing Values per Column:
# id           0
# species      0
# margin1      0
# margin2      0
# margin3      0
#             ..
# texture60    0
# texture61    0
# texture62    0
# texture63    0
# texture64    0
# Length: 181, dtype: int64

# %%
total_missing_values = df_train_dropped.isnull().sum().sum()
print(f"Total Missing Values across all Columns: {total_missing_values}")
# Out:
# Total Missing Values across all Columns: 0

# %% [markdown]
# We have no missing values at all.

# %% [markdown]
# ## 3. Standardizing and Encoding the Data
# Before we standardize the data, lets just take a look at how the data looks without standardizing, to see the difference between data before standardization and data after standardization.

# %%
#df_train_dropped.head()
#don't drop columns as this causes issues in stratification
df_train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0  ...   0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0  ...   0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0  ...   0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0  ...   0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0  ...   0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 1   0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 2   0.005859   0.000977   0.007812        0.0        0.0   0.000000
# 3   0.000000   0.000000   0.020508        0.0        0.0   0.017578
# 4   0.021484   0.000000   0.000000        0.0        0.0   0.000000
#
#    texture63  texture64
# 0   0.000000   0.025391
# 1   0.039062   0.022461
# 2   0.020508   0.002930
# 3   0.000000   0.047852
# 4   0.000000   0.031250
#
# [5 rows x 194 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import LabelEncoder

#as a prerequisite to stratified split, check standard scaling of all columns
#scaler = StandardScaler().fit(df_train_n.values)
#scaled_train = scaler.transform(df_train_n.values)

#labels = df_train['species_encoded']
#overwrite bad indices
label_encoder = LabelEncoder().fit(df_train['species'])
labels = label_encoder.transform(df_train['species'])
classes = list(label_encoder.classes_)
#drop unnecessary columns if possible
train = df_train.drop(['species', 'id'], axis=1)
test_ids= df_test['id']
test = df_test.drop('id', axis=1)
#for better prediction stratify both test and train datasets, also since test datasets isn't labelled

# %%
train.head()
# Out:
#     margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0  0.007812  0.023438  0.023438  0.003906  0.011719  0.009766  0.027344
# 1  0.005859  0.000000  0.031250  0.015625  0.025391  0.001953  0.019531
# 2  0.005859  0.009766  0.019531  0.007812  0.003906  0.005859  0.068359
# 3  0.000000  0.003906  0.023438  0.005859  0.021484  0.019531  0.023438
# 4  0.005859  0.003906  0.048828  0.009766  0.013672  0.015625  0.005859
#
#    margin8   margin9  margin10  ...  texture55  texture56  texture57  \
# 0      0.0  0.001953  0.033203  ...   0.007812   0.000000   0.002930
# 1      0.0  0.000000  0.007812  ...   0.000977   0.000000   0.000000
# 2      0.0  0.000000  0.044922  ...   0.154300   0.000000   0.005859
# 3      0.0  0.013672  0.017578  ...   0.000000   0.000977   0.000000
# 4      0.0  0.000000  0.005859  ...   0.096680   0.000000   0.021484
#
#    texture58  texture59  texture60  texture61  texture62  texture63  texture64
# 0   0.002930   0.035156        0.0        0.0   0.004883   0.000000   0.025391
# 1   0.000977   0.023438        0.0        0.0   0.000977   0.039062   0.022461
# 2   0.000977   0.007812        0.0        0.0   0.000000   0.020508   0.002930
# 3   0.000000   0.020508        0.0        0.0   0.017578   0.000000   0.047852
# 4   0.000000   0.000000        0.0        0.0   0.000000   0.000000   0.031250
#
# [5 rows x 192 columns]

# %% [raw]
# from sklearn.preprocessing import StandardScaler
#
# # Select only the numerical columns for standardization
# numerical_columns = df_train.select_dtypes(include=['float64', 'int64']).columns
#
# #scaler = StandardScaler()
# scaler = StandardScaler().fit(df_train[numerical_columns].values)
# scaled_train = scaler.transform(df_train[numerical_columns].values)
# # Fit the scaler on the training data and transform both training and test data
# df_train[numerical_columns] = scaler.fit_transform(df_train[numerical_columns])
# df_test[numerical_columns] = scaler.transform(df_test[numerical_columns])

# %% [raw]
# #df_train.head()
# scaled_train

# %% [markdown]
# As we can see, now we have negative values after we standardized the data with the **StandardScaler**. Before the standardization we had no negative values at all.

# %% [markdown]
# ## 4. Encoding Species
# The process of encoding the species attribute involves transforming categorical information into a numerical format that can be effectively utilized by machine learning models or deep neural networks as we are going to explore later on.

# %% [raw]
# from sklearn.preprocessing import LabelEncoder
#
# label_encoder = LabelEncoder()
# df_train['species_encoded'] = label_encoder.fit_transform(df_train['species'])
# labels = df_train['species_encoded']

# %%
df_train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0  ...   0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0  ...   0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0  ...   0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0  ...   0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0  ...   0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 1   0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 2   0.005859   0.000977   0.007812        0.0        0.0   0.000000
# 3   0.000000   0.000000   0.020508        0.0        0.0   0.017578
# 4   0.021484   0.000000   0.000000        0.0        0.0   0.000000
#
#    texture63  texture64
# 0   0.000000   0.025391
# 1   0.039062   0.022461
# 2   0.020508   0.002930
# 3   0.000000   0.047852
# 4   0.000000   0.031250
#
# [5 rows x 194 columns]

# %% [markdown]
# We can now see that an extra column has been added to our dataframe called **species_encoded** which has a numerical representation of the corresponding species.

# %% [markdown]
# ## Constructing the CNN model

# %% [markdown]
# ## 1) Setting X and Y values
# Divide each of the training and test sets into dependent and independent variables.

# %%
df_train.head()  ##for comparison purposes before filtering
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0  ...   0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0  ...   0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0  ...   0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0  ...   0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0  ...   0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 1   0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 2   0.005859   0.000977   0.007812        0.0        0.0   0.000000
# 3   0.000000   0.000000   0.020508        0.0        0.0   0.017578
# 4   0.021484   0.000000   0.000000        0.0        0.0   0.000000
#
#    texture63  texture64
# 0   0.000000   0.025391
# 1   0.039062   0.022461
# 2   0.020508   0.002930
# 3   0.000000   0.047852
# 4   0.000000   0.031250
#
# [5 rows x 194 columns]

# %%
df_test.head()
# Out:
#    id   margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0   4  0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 1   7  0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 2   9  0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 3  12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 4  13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
#
#    margin8   margin9  ...  texture55  texture56  texture57  texture58  \
# 0      0.0  0.005859  ...   0.006836   0.000000   0.015625   0.000977
# 1      0.0  0.033203  ...   0.000000   0.000000   0.006836   0.001953
# 2      0.0  0.011719  ...   0.128910   0.000000   0.000977   0.000000
# 3      0.0  0.003906  ...   0.012695   0.015625   0.002930   0.036133
# 4      0.0  0.005859  ...   0.000000   0.042969   0.016602   0.010742
#
#    texture59  texture60  texture61  texture62  texture63  texture64
# 0   0.015625        0.0        0.0   0.000000   0.003906   0.053711
# 1   0.013672        0.0        0.0   0.000977   0.037109   0.044922
# 2   0.000000        0.0        0.0   0.015625   0.000000   0.000000
# 3   0.013672        0.0        0.0   0.089844   0.000000   0.008789
# 4   0.041016        0.0        0.0   0.007812   0.009766   0.007812
#
# [5 rows x 193 columns]

# %% [markdown]
# Labels for the encoded species (to be dependent variable)
# The independent variables are all the rest

# %%
type(df_train_dropped.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [raw]
# from sklearn.model_selection import StratifiedShuffleSplit
# #as a prerequisite to stratified split, check standard scaling of all columns
# #scaler = StandardScaler().fit(df_train_n.values)
# #scaled_train = scaler.transform(df_train_n.values)
#
# labels = df_train['species_encoded']
# #overwrite bad indices
# label_encoder = LabelEncoder().fit(df_train['species'])
# labels = label_encoder.transform(df_train['species'])
# classes = list(label_encoder.classes_)
# #drop unnecessary columns if possible
# train = df_train.drop(['species', 'id'], axis=1)
# test_ids= df_test['id']
# test = df_test.drop('id', axis=1)
# #for better prediction stratify both test and train datasets, also since test datasets isn't labelled

# %%
#Before stratification
print(classes)   ##equivalent plot provided below
# Out:
# ['Acer_Capillipes', 'Acer_Circinatum', 'Acer_Mono', 'Acer_Opalus', 'Acer_Palmatum', 'Acer_Pictum', 'Acer_Platanoids', 'Acer_Rubrum', 'Acer_Rufinerve', 'Acer_Saccharinum', 'Alnus_Cordata', 'Alnus_Maximowiczii', 'Alnus_Rubra', 'Alnus_Sieboldiana', 'Alnus_Viridis', 'Arundinaria_Simonii', 'Betula_Austrosinensis', 'Betula_Pendula', 'Callicarpa_Bodinieri', 'Castanea_Sativa', 'Celtis_Koraiensis', 'Cercis_Siliquastrum', 'Cornus_Chinensis', 'Cornus_Controversa', 'Cornus_Macrophylla', 'Cotinus_Coggygria', 'Crataegus_Monogyna', 'Cytisus_Battandieri', 'Eucalyptus_Glaucescens', 'Eucalyptus_Neglecta', 'Eucalyptus_Urnigera', 'Fagus_Sylvatica', 'Ginkgo_Biloba', 'Ilex_Aquifolium', 'Ilex_Cornuta', 'Liquidambar_Styraciflua', 'Liriodendron_Tulipifera', 'Lithocarpus_Cleistocarpus', 'Lithocarpus_Edulis', 'Magnolia_Heptapeta', 'Magnolia_Salicifolia', 'Morus_Nigra', 'Olea_Europaea', 'Phildelphus', 'Populus_Adenopoda', 'Populus_Grandidentata', 'Populus_Nigra', 'Prunus_Avium', 'Prunus_X_Shmittii', 'Pterocarya_Stenoptera', 'Quercus_Afares', 'Quercus_Agrifolia', 'Quercus_Alnifolia', 'Quercus_Brantii', 'Quercus_Canariensis', 'Quercus_Castaneifolia', 'Quercus_Cerris', 'Quercus_Chrysolepis', 'Quercus_Coccifera', 'Quercus_Coccinea', 'Quercus_Crassifolia', 'Quercus_Crassipes', 'Quercus_Dolicholepis', 'Quercus_Ellipsoidalis', 'Quercus_Greggii', 'Quercus_Hartwissiana', 'Quercus_Ilex', 'Quercus_Imbricaria', 'Quercus_Infectoria_sub', 'Quercus_Kewensis', 'Quercus_Nigra', 'Quercus_Palustris', 'Quercus_Phellos', 'Quercus_Phillyraeoides', 'Quercus_Pontica', 'Quercus_Pubescens', 'Quercus_Pyrenaica', 'Quercus_Rhysophylla', 'Quercus_Rubra', 'Quercus_Semecarpifolia', 'Quercus_Shumardii', 'Quercus_Suber', 'Quercus_Texana', 'Quercus_Trojana', 'Quercus_Variabilis', 'Quercus_Vulcanica', 'Quercus_x_Hispanica', 'Quercus_x_Turneri', 'Rhododendron_x_Russellianum', 'Salix_Fragilis', 'Salix_Intergra', 'Sorbus_Aria', 'Tilia_Oliveri', 'Tilia_Platyphyllos', 'Tilia_Tomentosa', 'Ulmus_Bergmanniana', 'Viburnum_Tinus', 'Viburnum_x_Rhytidophylloides', 'Zelkova_Serrata']

# %%
scaler = StandardScaler().fit(train.values)
scaled_train = scaler.transform(train.values)

# %%
sss = StratifiedShuffleSplit(test_size=0.2, random_state=23)
##randomly stratify data
for train_index, test_index in sss.split(df_train, labels): 
    #if(train_index in df_train_dropped.columns and test_index in df_test_dropped.columns):
    X_train, X_test = scaled_train[train_index], scaled_train[test_index]
    y_train, y_test = labels[train_index], labels[test_index]

# %%
X_train.shape   #indices of train values
# Out:
# (792, 192)

# %% [markdown]
# ## 2) Preparing the features for the model layers
# Set the feature type as input to the CNN. This means that there are 3 types of input, an input for the margin , for the shape and for the texture. Then count each of the features(size of each input list) and count the unique values of y_train(number of classes)

# %%
pd.set_option('display.max_columns', None)

##drop id
#df_train = df_train.drop(['species', 'id'], axis=1)
#df_test_ids= df_test.id
#df_test = df_test.drop('id', axis=1)
df_train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8   margin9  margin10  margin11  \
# 0  0.011719  0.009766  0.027344      0.0  0.001953  0.033203  0.013672
# 1  0.025391  0.001953  0.019531      0.0  0.000000  0.007812  0.003906
# 2  0.003906  0.005859  0.068359      0.0  0.000000  0.044922  0.007812
# 3  0.021484  0.019531  0.023438      0.0  0.013672  0.017578  0.001953
# 4  0.013672  0.015625  0.005859      0.0  0.000000  0.005859  0.001953
#
#    margin12  margin13  margin14  margin15  margin16  margin17  margin18  \
# 0  0.019531  0.066406  0.000000  0.029297       0.0  0.031250  0.011719
# 1  0.027344  0.023438  0.000000  0.033203       0.0  0.009766  0.009766
# 2  0.011719  0.021484  0.001953  0.025391       0.0  0.009766  0.011719
# 3  0.019531  0.001953  0.003906  0.035156       0.0  0.005859  0.000000
# 4  0.044922  0.041016  0.011719  0.041016       0.0  0.009766  0.015625
#
#    margin19  margin20  margin21  margin22  margin23  margin24  margin25  \
# 0  0.000000  0.025391  0.023438  0.001953       0.0  0.015625  0.000000
# 1  0.007812  0.007812  0.019531  0.007812       0.0  0.000000  0.007812
# 2  0.007812  0.005859  0.041016  0.001953       0.0  0.015625  0.000000
# 3  0.001953  0.003906  0.039062  0.009766       0.0  0.009766  0.005859
# 4  0.011719  0.007812  0.021484  0.000000       0.0  0.000000  0.015625
#
#    margin26  margin27  margin28  margin29  margin30  margin31  margin32  \
# 0  0.031250  0.000000  0.013672  0.029297  0.015625  0.011719  0.003906
# 1  0.027344  0.003906  0.037109  0.007812  0.048828  0.054688  0.027344
# 2  0.009766  0.001953  0.009766  0.009766  0.015625  0.005859  0.000000
# 3  0.027344  0.001953  0.017578  0.003906  0.021484  0.027344  0.027344
# 4  0.009766  0.001953  0.017578  0.041016  0.005859  0.021484  0.013672
#
#    margin33  margin34  margin35  margin36  margin37  margin38  margin39  \
# 4   0.008789   0.017578   0.021484   0.061523   0.026367   0.132810
#
#    texture49  texture50  texture51  texture52  texture53  texture54  \
# 0   0.004883   0.015625   0.000000        0.0   0.006836   0.037109
# 1   0.035156   0.007812   0.000000        0.0   0.053711   0.036133
# 2   0.010742   0.008789   0.000000        0.0   0.000977   0.000000
# 3   0.006836   0.017578   0.004883        0.0   0.006836   0.022461
# 4   0.000000   0.000000   0.000000        0.0   0.000000   0.001953
#
#    texture55  texture56  texture57  texture58  texture59  texture60  \
# 0   0.007812   0.000000   0.002930   0.002930   0.035156        0.0
# 1   0.000977   0.000000   0.000000   0.000977   0.023438        0.0
# 2   0.154300   0.000000   0.005859   0.000977   0.007812        0.0
# 3   0.000000   0.000977   0.000000   0.000000   0.020508        0.0
# 4   0.096680   0.000000   0.021484   0.000000   0.000000        0.0
#
#    texture61  texture62  texture63  texture64
# 0        0.0   0.004883   0.000000   0.025391
# 1        0.0   0.000977   0.039062   0.022461
# 2        0.0   0.000000   0.020508   0.002930
# 3        0.0   0.017578   0.000000   0.047852
# 4        0.0   0.000000   0.000000   0.031250

# %%
import numpy as np

margin_cols = [col for col in df_train.columns if 'margin' in col]
nb_margins = len(margin_cols)
print('Number of margin features', nb_margins)
shape_cols = [col for col in df_train.columns if 'shape' in col]
nb_shape = len(shape_cols)
print('Number of shape features', nb_shape)
texture_cols = [col for col in df_train.columns if 'texture' in col]
nb_texture = len(texture_cols)
print('Number of texture features', nb_texture)
# Out:
# Number of margin features 64
# Number of shape features 64
# Number of texture features 64

# %%
#type(classes)

# %%
#y_train.unique()
nb_classes = len(classes)
print('Number of dependent classes', nb_classes)
# Out:
# Number of dependent classes 99

# %% [markdown]
# Use the highest number of features, so the data size is balanced

# %%
nb_features = 64
nb_classes = 99
#print(X_train_r)

# %%
# reshape train data into 3 different features
X_train_r = np.zeros((len(X_train), nb_features, 3))
X_train_r[:, :, 0] = X_train[:, :nb_features]  ##margin type features take first 64
X_train_r[:, :, 1] = X_train[:, nb_features:128] ##shape type features take second 64 (64*2)
X_train_r[:, :, 2] = X_train[:, 128:]##texture type features take last 64 from number (64*2) to end

# %%
##repeat for test dataset
X_test_r = np.zeros((len(X_test), nb_features, 3))
X_test_r[:, :, 0] = X_test[:, :nb_features]
X_test_r[:, :, 1] = X_test[:, nb_features:128]
X_test_r[:, :, 2] = X_test[:, 128:]

# %%
X_test[0]
# Out:
# array([ 1.09734942e+00,  1.12595348e+00, -2.85611483e-02, -4.75883323e-01,
#        -5.63515031e-01,  8.35559086e-01,  9.11566627e-01, -3.95064141e-01,
#        -3.65273905e-01,  5.54997118e-02,  8.69355054e-01, -5.21567293e-01,
#         1.21775347e+00, -4.59817142e-01, -9.57031177e-01, -1.05087609e-01,
#         4.59682641e-02, -2.70881833e-02,  3.61665429e-01, -5.50622328e-01,
#        -5.81838705e-01, -6.07456784e-01, -2.31746723e-01, -5.94715527e-01,
#        -5.42628344e-01, -8.86208766e-01, -5.18691362e-01, -9.63686172e-01,
#         7.29448399e-01, -8.78918997e-01, -6.54978950e-01, -5.02595780e-01,
# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution1D, Dropout
from keras.optimizers import SGD
from sklearn.linear_model import SGDClassifier
#from keras.utils import np_utils
from keras.utils import to_categorical
import tensorflow as tf
# Out:
# Error in sys.excepthook:
# Traceback (most recent call last):
#   File "c:\python39\lib\site-packages\IPython\core\interactiveshell.py", line 1934, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'RuntimeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\python39\lib\site-packages\IPython\core\interactiveshell.py", line 1936, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\python39\lib\site-packages\IPython\core\ultratb.py", line 1105, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\python39\lib\site-packages\IPython\core\ultratb.py", line 999, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\python39\lib\site-packages\IPython\core\ultratb.py", line 851, in structured_traceback
#     assert etb is not None
# AssertionError
#
# Original exception was:
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# Error in sys.excepthook:
# Traceback (most recent call last):
#   File "c:\python39\lib\site-packages\IPython\core\interactiveshell.py", line 1934, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'RuntimeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\python39\lib\site-packages\IPython\core\interactiveshell.py", line 1936, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\python39\lib\site-packages\IPython\core\ultratb.py", line 1105, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\python39\lib\site-packages\IPython\core\ultratb.py", line 999, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\python39\lib\site-packages\IPython\core\ultratb.py", line 851, in structured_traceback
#     assert etb is not None
# AssertionError
#
# Original exception was:
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# Error in sys.excepthook:
# Traceback (most recent call last):
#   File "c:\python39\lib\site-packages\IPython\core\interactiveshell.py", line 1934, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'RuntimeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\python39\lib\site-packages\IPython\core\interactiveshell.py", line 1936, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "c:\python39\lib\site-packages\IPython\core\ultratb.py", line 1105, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\python39\lib\site-packages\IPython\core\ultratb.py", line 999, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\python39\lib\site-packages\IPython\core\ultratb.py", line 851, in structured_traceback
#     assert etb is not None
# AssertionError
#
# Original exception was:
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Input In [39], in <module>
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense, Activation, Flatten, Convolution1D, Dropout
#       3 from keras.optimizers import SGD
#
# File c:\python39\lib\site-packages\keras\__init__.py:3, in <module>
#       1 """DO NOT EDIT.
#       2
# ----> 3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
#       8 from keras import _tf_keras
#       9 from keras import activations
#
# File c:\python39\lib\site-packages\keras\__internal__\__init__.py:3, in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# File c:\python39\lib\site-packages\keras\__internal__\backend\__init__.py:3, in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# File c:\python39\lib\site-packages\keras\src\__init__.py:21, in <module>
#
# File c:\python39\lib\site-packages\keras\src\applications\__init__.py:18, in <module>
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras Applications are premade architectures with pre-trained weights."""
# ---> 18 from keras.src.applications.convnext import ConvNeXtBase
#      19 from keras.src.applications.convnext import ConvNeXtLarge
#      20 from keras.src.applications.convnext import ConvNeXtSmall
#
# File c:\python39\lib\site-packages\keras\src\applications\convnext.py:26, in <module>
#      17 """ConvNeXt models for Keras.
#      18
#      19 References:
#    (...)
#      22   (CVPR 2022)
#      23 """
#      25 import numpy as np
# ---> 26 import tensorflow.compat.v2 as tf
#      28 from keras.src import backend
#      29 from keras.src import initializers
#
# File c:\python39\lib\site-packages\tensorflow\__init__.py:48, in <module>
#      45 from tensorflow.python import tf2 as _tf2
#      46 _tf2.enable()
# ---> 48 from tensorflow._api.v2 import __internal__
#      49 from tensorflow._api.v2 import __operators__
#      50 from tensorflow._api.v2 import audio
#
# File c:\python39\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11, in <module>
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
#      13 from tensorflow._api.v2.__internal__ import feature_column
#
# File c:\python39\lib\site-packages\tensorflow\_api\v2\__internal__\distribute\__init__.py:8, in <module>
#       3 """Public API for tf._api.v2.__internal__.distribute namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__.distribute import combinations
#       9 from tensorflow._api.v2.__internal__.distribute import interim
#      10 from tensorflow._api.v2.__internal__.distribute import multi_process_runner
#
# File c:\python39\lib\site-packages\tensorflow\_api\v2\__internal__\distribute\combinations\__init__.py:8, in <module>
#       3 """Public API for tf._api.v2.__internal__.distribute.combinations namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.distribute.combinations import env # line: 456
#       9 from tensorflow.python.distribute.combinations import generate # line: 365
#      10 from tensorflow.python.distribute.combinations import in_main_process # line: 418
#
# File c:\python39\lib\site-packages\tensorflow\python\distribute\combinations.py:33, in <module>
#      29 import six
#      32 from tensorflow.python.client import session
# ---> 33 from tensorflow.python.distribute import collective_all_reduce_strategy
#      34 from tensorflow.python.distribute import distribute_lib
#      35 from tensorflow.python.distribute import multi_process_runner
#
# File c:\python39\lib\site-packages\tensorflow\python\distribute\collective_all_reduce_strategy.py:25, in <module>
#      23 from tensorflow.core.protobuf import tensorflow_server_pb2
#      24 from tensorflow.python.distribute import collective_util
# ---> 25 from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#      26 from tensorflow.python.distribute import cross_device_utils
#      27 from tensorflow.python.distribute import device_util
#
# File c:\python39\lib\site-packages\tensorflow\python\distribute\cross_device_ops.py:28, in <module>
#      26 from tensorflow.python.client import device_lib
#      27 from tensorflow.python.distribute import collective_util
# ---> 28 from tensorflow.python.distribute import cross_device_utils
#      29 from tensorflow.python.distribute import device_util
#      30 from tensorflow.python.distribute import distribute_utils
#
# File c:\python39\lib\site-packages\tensorflow\python\distribute\cross_device_utils.py:22, in <module>
#      19 from typing import Callable, List, Optional, Union
#      21 from tensorflow.python.distribute import collective_util
# ---> 22 from tensorflow.python.distribute import values as value_lib
#      23 from tensorflow.python.eager import backprop_util
#      24 from tensorflow.python.eager import context
#
# File c:\python39\lib\site-packages\tensorflow\python\distribute\values.py:23, in <module>
#      21 from tensorflow.core.protobuf import struct_pb2
#      22 from tensorflow.python.distribute import device_util
# ---> 23 from tensorflow.python.distribute import distribute_lib
#      24 from tensorflow.python.distribute import packed_distributed_variable as packed
#      25 from tensorflow.python.distribute import reduce_util
#
# File c:\python39\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:206, in <module>
#     204 from tensorflow.python.autograph.core import ag_ctx as autograph_ctx
#     205 from tensorflow.python.autograph.impl import api as autograph
# --> 206 from tensorflow.python.data.ops import dataset_ops
#     207 from tensorflow.python.distribute import collective_util
#     208 from tensorflow.python.distribute import device_util
#
# File c:\python39\lib\site-packages\tensorflow\python\data\__init__.py:21, in <module>
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File c:\python39\lib\site-packages\tensorflow\python\data\experimental\__init__.py:98, in <module>
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      94 @@UNKNOWN_CARDINALITY
#      95 """
#      97 # pylint: disable=unused-import
# ---> 98 from tensorflow.python.data.experimental import service
#      99 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#     100 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File c:\python39\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py:419, in <module>
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     416   job of ParameterServerStrategy).
#     417 """
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File c:\python39\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:25, in <module>
#      23 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      24 from tensorflow.python.data.experimental.service import _pywrap_utils
# ---> 25 from tensorflow.python.data.ops import dataset_ops
#      26 from tensorflow.python.data.ops import options as options_lib
#      27 from tensorflow.python.data.ops import structured_function
#
# File c:\python39\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:33, in <module>
#      31 from tensorflow.python.data.ops import dataset_autograph
#      32 from tensorflow.python.data.ops import debug_mode
# ---> 33 from tensorflow.python.data.ops import iterator_ops
#      34 from tensorflow.python.data.ops import options as options_lib
#      35 from tensorflow.python.data.ops import structured_function
#
# File c:\python39\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:41, in <module>
#      39 from tensorflow.python.saved_model import nested_structure_coder
#      40 from tensorflow.python.trackable import base as trackable
# ---> 41 from tensorflow.python.training.saver import BaseSaverBuilder
#      42 from tensorflow.python.util import _pywrap_utils
#      43 from tensorflow.python.util import deprecation
#
# File c:\python39\lib\site-packages\tensorflow\python\training\saver.py:50, in <module>
#      48 from tensorflow.python.saved_model.pywrap_saved_model import metrics
#      49 from tensorflow.python.trackable import base as trackable
# ---> 50 from tensorflow.python.training import py_checkpoint_reader
#      51 from tensorflow.python.training import training_util
#      52 from tensorflow.python.training.saving import saveable_object
#
# File c:\python39\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py:19, in <module>
#      17 from tensorflow.python.framework import errors_impl
#      18 from tensorflow.python.util import compat
# ---> 19 from tensorflow.python.util._pywrap_checkpoint_reader import CheckpointReader
#      20 from tensorflow.python.util.tf_export import tf_export
#      23 def error_translator(e):
#
# SystemError: initialization of _pywrap_checkpoint_reader raised unreported exception

# %%
model = Sequential()
model.add(Convolution1D(512, 1, input_shape=(nb_features, 3)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dropout(0.4))
model.add(Dense(2048, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dense(nb_classes))
model.add(Activation('softmax'))

# %%
y_train = tf.keras.utils.to_categorical(y_train, nb_classes)
y_test = tf.keras.utils.to_categorical(y_test, nb_classes)
###SGD LOSS
sgd = SGD(lr=0.01, nesterov=True, weight_decay=1e-6, momentum=0.9)
model.compile(loss='categorical_crossentropy',optimizer=sgd,metrics=['accuracy'])

nb_epoch = 15
model.fit(X_train_r, y_train, epochs=nb_epoch, validation_data=(X_test_r, y_test), batch_size=16)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 y_train = tf.keras.utils.to_categorical(y_train, nb_classes)
#       2 y_test = tf.keras.utils.to_categorical(y_test, nb_classes)
#       3 ###SGD LOSS
#
# File E:\Downloads\ANACONDA3\lib\site-packages\keras\src\utils\np_utils.py:62, in to_categorical(y, num_classes, dtype)
#      23 @keras_export("keras.utils.to_categorical")
#      24 def to_categorical(y, num_classes=None, dtype="float32"):
#      25     """Converts a class vector (integers) to binary class matrix.
#      26
#      27     E.g. for use with `categorical_crossentropy`.
#    (...)
#      60     [0. 0. 0. 0.]
#      61     """
# ---> 62     y = np.array(y, dtype="int")
#      63     input_shape = y.shape
#      65     # Shrink the last dimension if the shape is (..., 1).
#
# MemoryError: Unable to allocate 2.86 GiB for an array with shape (792, 99, 99, 99) and data type int32
