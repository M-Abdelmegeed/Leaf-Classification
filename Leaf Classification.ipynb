# %% [markdown]
# # Leaf Classification Problem
#
# ## Deep Learning Course Project Fall '23
#
# ### Members:
# - Mohammed Ahmed Abdelmegeed 19P1298
# - Sohayla Ihab Abdelmawgoud 19P7343
# - Nourhan Hatem Ibrahim 19P5821

# %% [markdown]
# ## Understanding The Dataset
#
# The dataset comprises a total of 1584 records, with 990 instances allocated for training in the `train.csv` file and the remaining 594 instances used for testing in the `test.csv` file.
#
# ### Attributes:
#
# - **id**: Identifier for each record
# - **margin1 - margin64**: Numerical features representing leaf margin characteristics
# - **shape1 - shape64**: Numerical features representing leaf shape characteristics
# - **texture1 - texture64**: Numerical features representing leaf texture characteristics
#
# The distribution of records in the dataset is as follows:
#
# - **Training Data (`train.csv`):** 990 records
# - **Testing Data (`test.csv`):** 594 records
#
# ### Images:
#
# The dataset includes a folder named **images** containing 1584 black and white JPG images of leaves. Each image corresponds to a record in the dataset and can be referenced using the respective **id**.

# %% [markdown]
# ## Loading & Exploring the Dataset

# %%
#importing the datasets

import pandas as pd

df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
df_train.set_index('id', inplace=True)
df_test.set_index('id', inplace=True)

# %%
df_train.describe()
# Out:
#           margin1     margin2     margin3     margin4     margin5     margin6  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  990.000000
# mean     0.017412    0.028539    0.031988    0.023280    0.014264    0.038579
# std      0.019739    0.038855    0.025847    0.028411    0.018390    0.052030
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.001953    0.001953    0.013672    0.005859    0.001953    0.000000
# 50%      0.009766    0.011719    0.025391    0.013672    0.007812    0.015625
# 75%      0.025391    0.041016    0.044922    0.029297    0.017578    0.056153
# max      0.087891    0.205080    0.156250    0.169920    0.111330    0.310550
#
#           margin7     margin8     margin9    margin10  ...   texture55  \
# count  990.000000  990.000000  990.000000  990.000000  ...  990.000000
# mean     0.019202    0.001083    0.007167    0.018639  ...    0.036501
# std      0.017511    0.002743    0.008933    0.016071  ...    0.063403
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.005859    0.000000    0.001953    0.005859  ...    0.000000
# 50%      0.015625    0.000000    0.005859    0.015625  ...    0.004883
# 75%      0.029297    0.000000    0.007812    0.027344  ...    0.043701
# max      0.091797    0.031250    0.076172    0.097656  ...    0.429690
#
#         texture56   texture57   texture58   texture59   texture60   texture61  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  990.000000
# mean     0.005024    0.015944    0.011586    0.016108    0.014017    0.002688
# std      0.019321    0.023214    0.025040    0.015335    0.060151    0.011415
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000977    0.000000    0.004883    0.000000    0.000000
# 50%      0.000000    0.005859    0.000977    0.012695    0.000000    0.000000
# 75%      0.000000    0.022217    0.009766    0.021484    0.000000    0.000000
# max      0.202150    0.172850    0.200200    0.106450    0.578130    0.151370
#
#         texture62   texture63   texture64
# count  990.000000  990.000000  990.000000
# mean     0.020291    0.008989    0.019420
# std      0.039040    0.013791    0.022768
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000977
# 50%      0.003906    0.002930    0.011719
# 75%      0.023438    0.012695    0.029297
# max      0.375980    0.086914    0.141600
#
# [8 rows x 192 columns]

# %%
df_test.describe()
# Out:
#           margin1     margin2     margin3     margin4     margin5     margin6  \
# count  594.000000  594.000000  594.000000  594.000000  594.000000  594.000000
# mean     0.017562    0.028425    0.031858    0.022556    0.014527    0.037497
# std      0.019585    0.038351    0.025719    0.028797    0.018029    0.051372
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.001953    0.001953    0.013672    0.005859    0.001953    0.000000
# 50%      0.009766    0.010743    0.023438    0.013672    0.007812    0.013672
# 75%      0.028809    0.041016    0.042969    0.027344    0.019531    0.056641
# max      0.085938    0.189450    0.167970    0.164060    0.093750    0.271480
#
#           margin7     margin8     margin9    margin10  ...   texture55  \
# count  594.000000  594.000000  594.000000  594.000000  ...  594.000000
# mean     0.019222    0.001085    0.007092    0.018798  ...    0.035291
# std      0.017122    0.002697    0.009515    0.016229  ...    0.064482
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.005859    0.000000    0.001953    0.005859  ...    0.000000
# 50%      0.015625    0.000000    0.005859    0.015625  ...    0.003906
# 75%      0.029297    0.000000    0.007812    0.027344  ...    0.038086
# max      0.087891    0.021484    0.083984    0.083984  ...    0.353520
#
#         texture56   texture57   texture58   texture59   texture60   texture61  \
# count  594.000000  594.000000  594.000000  594.000000  594.000000  594.000000
# mean     0.005923    0.015033    0.011762    0.015881    0.011217    0.002617
# std      0.026934    0.022318    0.024771    0.014898    0.052530    0.011204
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000977    0.000000    0.004883    0.000000    0.000000
# 50%      0.000000    0.005859    0.001953    0.012695    0.000000    0.000000
# 75%      0.000000    0.019531    0.010498    0.022461    0.000000    0.000000
# max      0.441410    0.153320    0.177730    0.083984    0.606450    0.123050
#
#         texture62   texture63   texture64
# count  594.000000  594.000000  594.000000
# mean     0.019975    0.009389    0.020970
# std      0.034704    0.013457    0.023407
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000977
# 50%      0.003418    0.002930    0.013184
# 75%      0.022461    0.014648    0.032227
# max      0.247070    0.086914    0.149410
#
# [8 rows x 192 columns]

# %% [markdown]
# Both train and test datasets have the same number of columns or features, 192 features

# %% [markdown]
# ## Checking out Images
#
# Plotting a 4 random images to get a sense of how the dataset and images we are working on look like.

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

images_folder_path = "images"

jpg_files = [f for f in os.listdir(images_folder_path) if f.endswith(".jpg")]

random_jpgs = random.sample(jpg_files, 4)

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

for i, jpg in enumerate(random_jpgs):
    img_path = os.path.join(images_folder_path, jpg)
    img = mpimg.imread(img_path)
    axs[i // 2, i % 2].imshow(img)
    axs[i // 2, i % 2].set_title(f"Image {i+1}: {jpg}")
    axs[i // 2, i % 2].axis('off')

plt.show()

# %% [markdown]
# ### Visualizing Correlation Between Attributes

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation_matrix = df_train.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True)
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 4 correlation_matrix = df_train.corr()
#       5 plt.figure(figsize=(12, 10))
#       6 sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True)
#
# File E:\Downloads\ANACONDA3\lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File E:\Downloads\ANACONDA3\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File E:\Downloads\ANACONDA3\lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File E:\Downloads\ANACONDA3\lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Acer_Opalus'

# %% [markdown]
# We can realize that a lot of attributes or features are really dependent on each other, hence we can drop a subset of them in order to make the training process much easier and less computationally expensive, but in order to do that, we have to identify all the highly correlated pairs first.

# %% [markdown]
# ## Preprocessing
#
# ### 1. Removing Highly Correlated Attributes
#
# The initial step in preprocessing involves the identification and removal of highly correlated attributes. This is crucial for mitigating multicollinearity, ensuring that the model isn't influenced by redundant information. Highly correlated attributes are detected through correlation analysis, and one feature from each correlated pair is dropped.
#
# ### 2. Checking for Missing Values and Duplicates
#
# Following the removal of highly correlated attributes, the dataset undergoes a check for missing values and duplicates. This step ensures data integrity and consistency.
#
# ### 3. Standardizing the Data
#
# Standardization becomes the next step to ensure that all numerical features are on a similar scale. This is achieved by subtracting the mean and dividing by the standard deviation of each feature.
#
# ### 4. Encoding Categorical Variables
#
# Encoding is applied to convert them into a format suitable for machine learning algorithms.

# %%
import numpy as np

correlation_threshold = 0.99

# print("Highly Correlated Feature Pairs:")
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > correlation_threshold:
            feature1 = correlation_matrix.columns[i]
            feature2 = correlation_matrix.columns[j]
            correlation_value = correlation_matrix.iloc[i, j]
#             print(f"{feature1} and {feature2} are highly correlated ({correlation_value:.2f})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       3 correlation_threshold = 0.99
#       5 # print("Highly Correlated Feature Pairs:")
# ----> 6 for i in range(len(correlation_matrix.columns)):
#       7     for j in range(i):
#       8         if abs(correlation_matrix.iloc[i, j]) > correlation_threshold:
#
# NameError: name 'correlation_matrix' is not defined

# %% [markdown]
# ## 1. Feature Selection: Highly Correlated Features
#
# The following pairs of features are highly correlated:
#
# 1. shape10 and shape9 (Correlation: 0.99)
# 2. shape11 and shape10 (Correlation: 0.99)
# 3. shape12 and shape11 (Correlation: 0.99)
# 4. shape13 and shape12 (Correlation: 0.99)
# 5. shape14 and shape13 (Correlation: 0.99)
# 6. shape15 and shape14 (Correlation: 0.99)
# 7. shape16 and shape15 (Correlation: 0.99)
# 8. shape17 and shape16 (Correlation: 0.99)
# 9. shape18 and shape17 (Correlation: 0.99)
# 10. shape19 and shape18 (Correlation: 0.99)
# 11. shape20 and shape19 (Correlation: 0.99)
# 12. shape21 and shape20 (Correlation: 0.99)
# 13. shape22 and shape21 (Correlation: 0.99)
# 14. shape23 and shape22 (Correlation: 0.99)
# 15. shape43 and shape42 (Correlation: 0.99)
# 16. shape44 and shape43 (Correlation: 0.99)
# 17. shape45 and shape44 (Correlation: 0.99)
# 18. shape46 and shape45 (Correlation: 0.99)
# 19. shape47 and shape46 (Correlation: 0.99)
# 20. shape48 and shape47 (Correlation: 0.99)
# 21. shape49 and shape48 (Correlation: 0.99)
# 22. shape50 and shape49 (Correlation: 0.99)
# 23. shape51 and shape50 (Correlation: 0.99)
# 24. shape52 and shape51 (Correlation: 0.99)
# 25. shape53 and shape52 (Correlation: 0.99)
# 26. shape54 and shape53 (Correlation: 0.99)
#
# To avoid multicollinearity and reduce redundancy, it is recommended to drop one feature from each highly correlated pair. Since you want to drop only features with odd shape numbers, the following features will be dropped:
#
# ### Dropping Features:
#
# The following features will be dropped:
#
# - **Features to Drop:**
#   - shape9, shape11, shape13, shape15, shape17, shape19, shape21, shape43, shape45, shape47, shape49, shape51, shape53

# %%
features_to_drop = ['shape9', 'shape11', 'shape13', 'shape15', 'shape17', 'shape19', 'shape21',
                    'shape43', 'shape45', 'shape47', 'shape49', 'shape51', 'shape53']
df_train = df_train.drop(columns = features_to_drop)
df_test = df_test.drop(columns = features_to_drop)

# %%
df_train.head()
# Out:
#                   species   margin1   margin2   margin3   margin4   margin5  \
# id
# 1             Acer_Opalus  0.007812  0.023438  0.023438  0.003906  0.011719
# 2   Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625  0.025391
# 3    Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812  0.003906
# 5         Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859  0.021484
# 6      Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766  0.013672
#
#      margin6   margin7  margin8   margin9  ...  texture55  texture56  \
# id                                         ...
# 1   0.009766  0.027344      0.0  0.001953  ...   0.007812   0.000000
# 2   0.001953  0.019531      0.0  0.000000  ...   0.000977   0.000000
# 3   0.005859  0.068359      0.0  0.000000  ...   0.154300   0.000000
# 5   0.019531  0.023438      0.0  0.013672  ...   0.000000   0.000977
# 6   0.015625  0.005859      0.0  0.000000  ...   0.096680   0.000000
#
#     texture57  texture58  texture59  texture60  texture61  texture62  \
# id
# 1    0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 2    0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 3    0.005859   0.000977   0.007812        0.0        0.0   0.000000
# 5    0.000000   0.000000   0.020508        0.0        0.0   0.017578
# 6    0.021484   0.000000   0.000000        0.0        0.0   0.000000
#
#     texture63  texture64
# id
# 1    0.000000   0.025391
# 2    0.039062   0.022461
# 3    0.020508   0.002930
# 5    0.000000   0.047852
# 6    0.000000   0.031250
#
# [5 rows x 180 columns]

# %% [markdown]
# We now have a total of 180 features, instead of 194. Of course more features could have been dropped if the **correlation_threshold** is reduced as it was set to 0.99.

# %%
df_test.head()
# Out:
#      margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# id
# 4   0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 7   0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 9   0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
#
#     margin8   margin9  margin10  ...  texture55  texture56  texture57  \
# id                               ...
# 4       0.0  0.005859  0.023438  ...   0.006836   0.000000   0.015625
# 7       0.0  0.033203  0.023438  ...   0.000000   0.000000   0.006836
# 9       0.0  0.011719  0.005859  ...   0.128910   0.000000   0.000977
# 12      0.0  0.003906  0.001953  ...   0.012695   0.015625   0.002930
# 13      0.0  0.005859  0.000000  ...   0.000000   0.042969   0.016602
#
#     texture58  texture59  texture60  texture61  texture62  texture63  \
# id
# 4    0.000977   0.015625        0.0        0.0   0.000000   0.003906
# 7    0.001953   0.013672        0.0        0.0   0.000977   0.037109
# 9    0.000000   0.000000        0.0        0.0   0.015625   0.000000
# 12   0.036133   0.013672        0.0        0.0   0.089844   0.000000
# 13   0.010742   0.041016        0.0        0.0   0.007812   0.009766
#
#     texture64
# id
# 4    0.053711
# 7    0.044922
# 9    0.000000
# 12   0.008789
# 13   0.007812
#
# [5 rows x 179 columns]

# %% [markdown]
# ## 2. Checking for Duplicates and Missing Values

# %% [markdown]
# ### Checking for duplicates

# %%
duplicates = df_train[df_train.duplicated()]
print("Duplicate Rows:")
print(duplicates)
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [species, margin1, margin2, margin3, margin4, margin5, margin6, margin7, margin8, margin9, margin10, margin11, margin12, margin13, margin14, margin15, margin16, margin17, margin18, margin19, margin20, margin21, margin22, margin23, margin24, margin25, margin26, margin27, margin28, margin29, margin30, margin31, margin32, margin33, margin34, margin35, margin36, margin37, margin38, margin39, margin40, margin41, margin42, margin43, margin44, margin45, margin46, margin47, margin48, margin49, margin50, margin51, margin52, margin53, margin54, margin55, margin56, margin57, margin58, margin59, margin60, margin61, margin62, margin63, margin64, shape1, shape2, shape3, shape4, shape5, shape6, shape7, shape8, shape10, shape12, shape14, shape16, shape18, shape20, shape22, shape23, shape24, shape25, shape26, shape27, shape28, shape29, shape30, shape31, shape32, shape33, shape34, shape35, shape36, shape37, shape38, shape39, shape40, shape41, shape42, ...]
# Index: []
#
# [0 rows x 180 columns]

# %% [markdown]
# We have 0 rows in the duplicates dataframe, hence we have no duplicate rows at all.

# %% [markdown]
# ### Checking for missing values

# %%
missing_values = df_train.isnull().sum()
print("\nMissing Values per Column:")
print(missing_values)
# Out:
# Missing Values per Column:
# species      0
# margin1      0
# margin2      0
# margin3      0
# margin4      0
#             ..
# texture60    0
# texture61    0
# texture62    0
# texture63    0
# texture64    0
# Length: 180, dtype: int64

# %%
total_missing_values = df_train.isnull().sum().sum()
print(f"Total Missing Values across all Columns: {total_missing_values}")
# Out:
# Total Missing Values across all Columns: 0

# %% [markdown]
# We have no missing values at all.

# %% [markdown]
# ## 3. Standardizing the Data
# Before we standardize the data, lets just take a look at how the data looks without standardizing, to see the difference between data before standardization and data after standardization.

# %%
df_train.head()
# Out:
#                   species   margin1   margin2   margin3   margin4   margin5  \
# id
# 1             Acer_Opalus  0.007812  0.023438  0.023438  0.003906  0.011719
# 2   Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625  0.025391
# 3    Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812  0.003906
# 5         Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859  0.021484
# 6      Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766  0.013672
#
#      margin6   margin7  margin8   margin9  ...  texture55  texture56  \
# id                                         ...
# 1   0.009766  0.027344      0.0  0.001953  ...   0.007812   0.000000
# 2   0.001953  0.019531      0.0  0.000000  ...   0.000977   0.000000
# 3   0.005859  0.068359      0.0  0.000000  ...   0.154300   0.000000
# 5   0.019531  0.023438      0.0  0.013672  ...   0.000000   0.000977
# 6   0.015625  0.005859      0.0  0.000000  ...   0.096680   0.000000
#
#     texture57  texture58  texture59  texture60  texture61  texture62  \
# id
# 1    0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 2    0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 3    0.005859   0.000977   0.007812        0.0        0.0   0.000000
# 5    0.000000   0.000000   0.020508        0.0        0.0   0.017578
# 6    0.021484   0.000000   0.000000        0.0        0.0   0.000000
#
#     texture63  texture64
# id
# 1    0.000000   0.025391
# 2    0.039062   0.022461
# 3    0.020508   0.002930
# 5    0.000000   0.047852
# 6    0.000000   0.031250
#
# [5 rows x 180 columns]

# %%
from sklearn.preprocessing import StandardScaler

# Select only the numerical columns for standardization
numerical_columns = df_train.select_dtypes(include=['float64', 'int64']).columns

scaler = StandardScaler()

# Fit the scaler on the training data and transform both training and test data
df_train[numerical_columns] = scaler.fit_transform(df_train[numerical_columns])
df_test[numerical_columns] = scaler.transform(df_test[numerical_columns])

# %%
df_train.head()
# Out:
#                   species   margin1   margin2   margin3   margin4   margin5  \
# id
# 1             Acer_Opalus -0.486611 -0.131357 -0.330956 -0.682244 -0.138444
# 2   Pterocarya_Stenoptera -0.585602 -0.734880 -0.028561 -0.269558  0.605389
# 3    Quercus_Hartwissiana -0.585602 -0.483408 -0.482192 -0.544694 -0.563515
# 5         Tilia_Tomentosa -0.882575 -0.634302 -0.330956 -0.613469  0.392826
# 6      Quercus_Variabilis -0.585602 -0.634302  0.651866 -0.475883 -0.032190
#
#      margin6   margin7   margin8   margin9  ...  texture55  texture56  \
# id                                          ...
# 1  -0.554066  0.465218 -0.395064 -0.584019  ...  -0.452710  -0.260149
# 2  -0.704306  0.018812 -0.395064 -0.802765  ...  -0.560567  -0.260149
# 3  -0.629196  2.808662 -0.395064 -0.802765  ...   1.858873  -0.260149
# 5  -0.366289  0.242044 -0.395064  0.728566  ...  -0.575984  -0.209558
# 6  -0.441400 -0.762355 -0.395064 -0.802765  ...   0.949628  -0.260149
#
#     texture57  texture58  texture59  texture60  texture61  texture62  \
# id
# 1   -0.560872  -0.345848   1.242752  -0.233151   -0.23561  -0.394871
# 2   -0.687151  -0.423884   0.478218  -0.233151   -0.23561  -0.494974
# 3   -0.434636  -0.423884  -0.541291  -0.233151   -0.23561  -0.520012
# 5   -0.687151  -0.462921   0.287052  -0.233151   -0.23561  -0.069525
# 6    0.238782  -0.462921  -1.050981  -0.233151   -0.23561  -0.520012
#
#     texture63  texture64
# id
# 1   -0.652143   0.262397
# 2    2.181670   0.133641
# 3    0.835641  -0.724631
# 5   -0.652143   1.249425
# 6   -0.652143   0.519866
#
# [5 rows x 180 columns]

# %% [markdown]
# As we can see, now we have negative values after we standardized the data with the **StandardScaler**. Before the standardization we had no negative values at all.

# %% [markdown]
# ## 4. Encoding Species
# The process of encoding the species attribute involves transforming categorical information into a numerical format that can be effectively utilized by machine learning models or deep neural networks as we are going to explore later on.

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df_train['species_encoded'] = label_encoder.fit_transform(df_train['species'])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6880\86009858.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_train['species_encoded'] = label_encoder.fit_transform(df_train['species'])

# %%
df_train.head()
# Out:
#                   species   margin1   margin2   margin3   margin4   margin5  \
# id
# 1             Acer_Opalus -0.486611 -0.131357 -0.330956 -0.682244 -0.138444
# 2   Pterocarya_Stenoptera -0.585602 -0.734880 -0.028561 -0.269558  0.605389
# 3    Quercus_Hartwissiana -0.585602 -0.483408 -0.482192 -0.544694 -0.563515
# 5         Tilia_Tomentosa -0.882575 -0.634302 -0.330956 -0.613469  0.392826
# 6      Quercus_Variabilis -0.585602 -0.634302  0.651866 -0.475883 -0.032190
#
#      margin6   margin7   margin8   margin9  ...  texture56  texture57  \
# id                                          ...
# 1  -0.554066  0.465218 -0.395064 -0.584019  ...  -0.260149  -0.560872
# 2  -0.704306  0.018812 -0.395064 -0.802765  ...  -0.260149  -0.687151
# 3  -0.629196  2.808662 -0.395064 -0.802765  ...  -0.260149  -0.434636
# 5  -0.366289  0.242044 -0.395064  0.728566  ...  -0.209558  -0.687151
# 6  -0.441400 -0.762355 -0.395064 -0.802765  ...  -0.260149   0.238782
#
#     texture58  texture59  texture60  texture61  texture62  texture63  \
# id
# 1   -0.345848   1.242752  -0.233151   -0.23561  -0.394871  -0.652143
# 2   -0.423884   0.478218  -0.233151   -0.23561  -0.494974   2.181670
# 3   -0.423884  -0.541291  -0.233151   -0.23561  -0.520012   0.835641
# 5   -0.462921   0.287052  -0.233151   -0.23561  -0.069525  -0.652143
# 6   -0.462921  -1.050981  -0.233151   -0.23561  -0.520012  -0.652143
#
#     texture64  species_encoded
# id
# 1    0.262397                3
# 2    0.133641               49
# 3   -0.724631               65
# 5    1.249425               94
# 6    0.519866               84
#
# [5 rows x 181 columns]

# %% [markdown]
# We can now see that an extra column has been added to our dataframe called **species_encoded** which has a numerical representation of the corresponding species.

# %% [markdown]
# ## Constructing the CNN model

# %% [markdown]
# ## 1) Setting X and Y values
# Divide each of the training and test sets into dependent and independent variables.

# %%
df_train.head()
# Out:
#                   species   margin1   margin2   margin3   margin4   margin5  \
# id
# 1             Acer_Opalus -0.486611 -0.131357 -0.330956 -0.682244 -0.138444
# 2   Pterocarya_Stenoptera -0.585602 -0.734880 -0.028561 -0.269558  0.605389
# 3    Quercus_Hartwissiana -0.585602 -0.483408 -0.482192 -0.544694 -0.563515
# 5         Tilia_Tomentosa -0.882575 -0.634302 -0.330956 -0.613469  0.392826
# 6      Quercus_Variabilis -0.585602 -0.634302  0.651866 -0.475883 -0.032190
#
#      margin6   margin7   margin8   margin9  ...  texture56  texture57  \
# id                                          ...
# 1  -0.554066  0.465218 -0.395064 -0.584019  ...  -0.260149  -0.560872
# 2  -0.704306  0.018812 -0.395064 -0.802765  ...  -0.260149  -0.687151
# 3  -0.629196  2.808662 -0.395064 -0.802765  ...  -0.260149  -0.434636
# 5  -0.366289  0.242044 -0.395064  0.728566  ...  -0.209558  -0.687151
# 6  -0.441400 -0.762355 -0.395064 -0.802765  ...  -0.260149   0.238782
#
#     texture58  texture59  texture60  texture61  texture62  texture63  \
# id
# 1   -0.345848   1.242752  -0.233151   -0.23561  -0.394871  -0.652143
# 2   -0.423884   0.478218  -0.233151   -0.23561  -0.494974   2.181670
# 3   -0.423884  -0.541291  -0.233151   -0.23561  -0.520012   0.835641
# 5   -0.462921   0.287052  -0.233151   -0.23561  -0.069525  -0.652143
# 6   -0.462921  -1.050981  -0.233151   -0.23561  -0.520012  -0.652143
#
#     texture64  species_encoded
# id
# 1    0.262397                3
# 2    0.133641               49
# 3   -0.724631               65
# 5    1.249425               94
# 6    0.519866               84
#
# [5 rows x 181 columns]

# %% [markdown]
# Labels for the encoded species (to be dependent variable)
# The independent variables are all the rest

# %%
labels = df_train['species_encoded']
y_train = labels

X_train = df_train.loc[:, df_train.columns != 'species_encoded']
X_train = X_train.loc[:, X_train.columns != 'species']
X_train = X_train.loc[:, X_train.columns != 'id']

# %%
#X_train.head()  ##correct result with all the independent variables

# %%
#repeat for test set
#insert labels dependent variable for test set (required)
#df_test.insert(0, 'species_encoded', 0)
y_test = df_test['species_encoded']
X_test = df_test.loc[:, df_test.columns != 'species_encoded']
X_test = X_test.loc[:, X_test.columns != 'id']

# %%
#X_test.head()  ##correct result with all the independent variables
# Out:
# id
# 4     0
# 7     0
# 9     0
# 12    0
# 13    0
# Name: species_encoded, dtype: int64

# %% [markdown]
# ## 2) Preparing the features for the model layers
# Set the feature type as input to the CNN. This means that there are 3 types of input, an input for the margin , for the shape and for the texture. Then count each of the features(size of each input list) and count the unique values of y_train(number of classes)

# %%
pd.set_option('display.max_columns', None)
X_train.head()
# Out:
#      margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# id
# 1  -0.486611 -0.131357 -0.330956 -0.682244 -0.138444 -0.554066  0.465218
# 2  -0.585602 -0.734880 -0.028561 -0.269558  0.605389 -0.704306  0.018812
# 3  -0.585602 -0.483408 -0.482192 -0.544694 -0.563515 -0.629196  2.808662
# 5  -0.882575 -0.634302 -0.330956 -0.613469  0.392826 -0.366289  0.242044
# 6  -0.585602 -0.634302  0.651866 -0.475883 -0.032190 -0.441400 -0.762355
#
#      margin8   margin9  margin10  margin11  margin12  margin13  margin14  \
# id
# 1  -0.395064 -0.584019  0.906636 -0.404139  0.644338  0.543066 -0.607031
# 2  -0.395064 -0.802765 -0.674054 -0.778711  1.310607 -0.384613 -0.607031
# 3  -0.395064 -0.802765  1.636190 -0.628898 -0.021845 -0.426800 -0.459817
# 5  -0.395064  0.728566 -0.066082 -0.853618  0.644338 -0.848474 -0.312603
# 6  -0.395064 -0.802765 -0.795636 -0.853618  2.809604 -0.005104  0.276330
#
#     margin15  margin16  margin17  margin18  margin19  margin20  margin21  \
# id
# 1   0.959250 -0.105088  1.490593 -0.394286 -0.852978  1.267718  0.221417
# 2   1.232985 -0.105088 -0.495731 -0.486085 -0.313167 -0.550622  0.020577
# 3   0.685516 -0.105088 -0.495731 -0.394286 -0.313167 -0.752637  1.125015
# 5   1.369852 -0.105088 -0.856957 -0.945129 -0.718025 -0.954652  1.024570
# 6   1.780524 -0.105088 -0.495731 -0.210687 -0.043193 -0.550622  0.120971
#
#     margin22  margin23  margin24  margin25  margin26  margin27  margin28  \
# id
# 1  -0.415944 -0.231747  0.620501 -0.696191  1.018261 -0.518691 -0.132137
# 5    -0.26082  -0.345335  -0.789066   3.654827  -0.101424   2.716934
# 6    -0.26082  -0.362081   2.291663   0.292761  -0.446303  -0.380073
#
#     texture42  texture43  texture44  texture45  texture46  texture47  \
# id
# 1   -0.461871   0.476648   0.255221  -0.538224  -0.010475   1.035146
# 2   -0.553627   2.645178  -0.375999  -0.352897  -0.307393  -0.429798
# 3   -0.553627  -0.770277  -0.418078   0.295796  -0.047571   0.180569
# 5   -0.553627   1.235650   0.654999  -0.769907  -0.752808   0.546852
# 6   -0.553627  -0.282355  -0.165585   0.249440   1.511325   0.485784
#
#     texture48  texture49  texture50  texture51  texture52  texture53  \
# id
# 1   -0.529280  -0.516651  -0.122891  -0.396582  -0.526069  -0.352672
# 2   -0.496557   1.784351  -0.408583  -0.396582  -0.526069   1.813144
# 3    1.337005  -0.071318  -0.372857  -0.396582  -0.526069  -0.623382
# 5   -0.562037  -0.368207  -0.051477  -0.250318  -0.526069  -0.352672
# 6    3.890775  -0.887800  -0.694238  -0.396582  -0.526069  -0.668524
#
#     texture54  texture55  texture56  texture57  texture58  texture59  \
# id
# 1    0.549672  -0.452710  -0.260149  -0.560872  -0.345848   1.242752
# 2    0.513950  -0.560567  -0.260149  -0.687151  -0.423884   0.478218
# 3   -0.808555   1.858873  -0.260149  -0.434636  -0.423884  -0.541291
# 5    0.013540  -0.575984  -0.209558  -0.687151  -0.462921   0.287052
# 6   -0.737073   0.949628  -0.260149   0.238782  -0.462921  -1.050981
#
#     texture60  texture61  texture62  texture63  texture64
# id
# 1   -0.233151   -0.23561  -0.394871  -0.652143   0.262397
# 2   -0.233151   -0.23561  -0.494974   2.181670   0.133641
# 3   -0.233151   -0.23561  -0.520012   0.835641  -0.724631
# 5   -0.233151   -0.23561  -0.069525  -0.652143   1.249425
# 6   -0.233151   -0.23561  -0.520012  -0.652143   0.519866

# %%
import numpy as np

margin_cols = [col for col in X_train.columns if 'margin' in col]
nb_margins = len(margin_cols)
print('Number of margin features', nb_margins)
shape_cols = [col for col in X_train.columns if 'shape' in col]
nb_shape = len(shape_cols)
print('Number of shape features', nb_shape)
texture_cols = [col for col in X_train.columns if 'texture' in col]
nb_texture = len(texture_cols)
print('Number of texture features', nb_texture)
# Out:
# Number of margin features 64
# Number of shape features 51
# Number of texture features 64

# %%
y_train.unique()
nb_classes = len(y_train.unique())
print('Number of dependent classes', nb_classes)
# Out:
# Number of dependent classes 99

# %% [markdown]
# Use the highest number of features, so the data size is balanced

# %%
nb_features = 64
nb_classes = 99
#print(X_train_r)

# %%
# reshape train data into 3 different features
X_train_r = np.zeros((len(X_train), nb_features, 3))
X_train_r[:, :, 0] = X_train.iloc[:, :nb_features]
#X_train_r[:, :, 1] = X_train.iloc[:, nb_features:115] ##handled separately
##first input size = 64, second input size = 51, third input size = 64
X_train_r[:, :, 2] = X_train.iloc[:, 115:]

# %%
##repeat for test dataset

# %% [markdown]
# ## 3) Constructing the model

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution1D, Dropout
from keras.optimizers import SGD
from keras.utils import np_utils

# %%
model = Sequential()
model.add(Convolution1D(512, 1, input_shape=(nb_features, 3)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dropout(0.4))
model.add(Dense(2048, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dense(nb_class))
model.add(Activation('softmax'))
